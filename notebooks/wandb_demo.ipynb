# %%
# !wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
/mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py

# %% [markdown]
# ### Data Exploration

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py -d mnist -e 10 -o adam -nhl 2 -sz 128 -a relu --experiment_group data_exploration
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ setting up run fa9778ky (0.5s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260227_135332-fa9778ky
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run glowing-sea-1
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# ...

# %% [markdown]
# ### Hyper Parameter Sweep

# %%
# !wandb sweep /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/sweep.yaml

# %%
# !wandb agent ae22b007-indian-institute-of-technology-madras/assignment_folder-notebooks_src/23lcu7ly --count 100


# Not possible to run it from this notebook. Have run it from terminal

# %% [markdown]
# ### Optimizer Showdown

# %%
for opt in ["sgd","momentum","rmsprop","nag"]: 
    # !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py \
        -d mnist -e 10 -o $opt -nhl 3 -sz 128 -a relu -lr 0.01 --experiment_group optimizer_showdown
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ setting up run wm9sf7wp (0.5s)
# wandb: ⣟ setting up run wm9sf7wp (0.5s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260227_223836-wm9sf7wp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run effortless-pine-1
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# ...

# %% [markdown]
# ### Vanishing Gradient

# %%
for act in ["sigmoid","relu"]: 
    # !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py \
        -d mnist -e 10 -o rmsprop -nhl 3 -sz 128 -a $act -lr 0.01 --experiment_group vanishing_gradient
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ setting up run 0b2ewz4f (0.5s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260227_234107-0b2ewz4f
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run solar-universe-11
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# ...

# %% [markdown]
# ### Dead Neuron Investigation

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py -d mnist -e 20 -o rmsprop -nhl 3 -sz 128 -a relu -lr 0.1 --experiment_group dead_neuron_relu
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ setting up run 2p9gh24z (0.5s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_001448-2p9gh24z
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crisp-surf-15
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# ...

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py -d mnist -e 20 -o rmsprop -nhl 3 -sz 128 -a tanh -lr 0.1 --experiment_group dead_neuron_relu
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_003128-9n1n55tc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cerulean-butterfly-16
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# wandb: 🚀 View run at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder/runs/9n1n55tc
# wandb: ⢿ updating run metadata (0.0s)
# ...

# %% [markdown]
# ### Loss Function Comparison

# %%
for loss in ["mse", "cross_entropy"]:
    # !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py  \
        -d mnist \
        -e 10 \
        -o adam \
        -nhl 3 \
        -sz 128 \
        -a relu \
        -lr 0.001 \
        -l $loss \
        --experiment_group debug_test
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_104030-59bnkdtn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run prime-sun-21
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# wandb: 🚀 View run at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder/runs/59bnkdtn
# wandb: ⢿ updating run metadata (0.0s)
# ...

# %% [markdown]
# ### Global Performance Overlay

# %% [markdown]
# ### RUNNING AND SAVING BEST MODEL

# %%
# !python src/train.py \
    -d mnist \
    -e 20 \
    -b 64 \
    -o rmsprop \
    -nhl 4 \
    -sz 128 \
    -a relu \
    -lr 0.001 \
    -l cross_entropy \
    -wd 0 \
    -wi xavier \
    --experiment_group best_model_retrain \
    --model_save_path models/best_sweep_model.pkl
    
# Don't run this from here, it can be run from terminal much easily inorder to save the best model. These are the configuration for best model
# Out:
# python: can't open file '/mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/src/train.py': [Errno 2] No such file or directory

# %% [markdown]
# ### Error Analysis

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/inference.py --model_path /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/models/model.pkl --dataset mnist
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_223317-h5n9r20r
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run evaluation_run
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# wandb: 🚀 View run at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder/runs/h5n9r20r
# accuracy: 0.9770
# precision: 0.9770
# recall: 0.9768
# ...

# %% [markdown]
# ### Weight Initialization and Symmetry

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py -d mnist -e 5 -o rmsprop -nhl 4 -lr 0.001 -sz 128 -a relu -wi zeros --experiment_group weight_init_analyse
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ setting up run md3yy3tr (0.0s)
# wandb: ⣻ setting up run md3yy3tr (0.0s)
# wandb: ⣽ setting up run md3yy3tr (0.0s)
# wandb: ⣾ setting up run md3yy3tr (0.0s)
# wandb: ⣷ setting up run md3yy3tr (0.0s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_221148-md3yy3tr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run misunderstood-universe-27
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# ...

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py -d mnist -e 5 -o rmsprop -nhl 4 -sz 128  -lr 0.001 -a relu -wi xavier --experiment_group weight_init_analyse
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ setting up run 7x23lhx8 (0.0s)
# wandb: ⣻ setting up run 7x23lhx8 (0.0s)
# wandb: ⣽ setting up run 7x23lhx8 (0.0s)
# wandb: ⣾ setting up run 7x23lhx8 (0.0s)
# wandb: ⣷ setting up run 7x23lhx8 (0.0s)
# wandb: ⣯ setting up run 7x23lhx8 (0.5s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_221502-7x23lhx8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run olive-sponge-28
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# ...

# %% [markdown]
# ### Performance on MNIST Model

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py \
    -d fashion-mnist \
    -e 20 \
    -b 64 \
    -o rmsprop \
    -nhl 4 \
    -sz 128 \
    -a relu \
    -lr 0.001 \
    -l cross_entropy \
    -wd 0 \
    -wi xavier \
    --experiment_group fashion_transfer
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_223501-wmvnh1vz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crimson-flower-30
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# wandb: 🚀 View run at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder/runs/wmvnh1vz
# wandb: ⢿ updating run metadata (0.0s)
# ...

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py \
    -d fashion-mnist \
    -e 20 \
    -b 64 \
    -o momentum \
    -nhl 2 \
    -sz 128 \
    -a sigmoid \
    -lr 0.1 \
    -l cross_entropy \
    -wd 0 \
    -wi xavier \
    --experiment_group fashion_transfer
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ setting up run 213lsqse (0.0s)
# wandb: ⣻ setting up run 213lsqse (0.0s)
# wandb: ⣽ setting up run 213lsqse (0.0s)
# wandb: ⣾ setting up run 213lsqse (0.0s)
# wandb: ⣷ setting up run 213lsqse (0.0s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/notebooks/wandb/run-20260228_224732-213lsqse
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run effortless-glade-31
# wandb: ⭐️ View project at https://wandb.ai/ae22b007-indian-institute-of-technology-madras/assignment_folder
# ...

# %%
# !python /mnt/c/Users/USER/desktop/semester_8/Deep_learning_assignments/assignment_folder/src/train.py \
    -d fashion-mnist \
    -e 20 \
    -b 64 \
    -o momentum \
    -nhl 3 \
    -sz 128 \
    -a relu \
    -lr 0.01 \
    -l cross_entropy \
    -wd 0 \
    -wi xavier \
    --experiment_group fashion_transfer
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/priyavrat/.netrc.
# wandb: Currently logged in as: ae22b007 (ae22b007-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ setting up run ithy368t (0.5s)
# wandb: ⣟ setting up run ithy368t (0.5s)
# wandb: ⡿ setting up run ithy368t (0.5s)
# wandb: ⢿ setting up run ithy368t (0.5s)
# wandb: ⣻ setting up run ithy368t (0.5s)
# wandb: ⣽ setting up run ithy368t (1.0s)
# wandb: ⣾ setting up run ithy368t (1.0s)
# wandb: ⣷ setting up run ithy368t (1.0s)
# wandb: ⣯ setting up run ithy368t (1.0s)
# wandb: ⣟ setting up run ithy368t (1.0s)
# wandb: Tracking run with wandb version 0.25.0
# ...
